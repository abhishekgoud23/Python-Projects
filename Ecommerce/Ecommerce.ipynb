# %%
def partition(ls,lo,hi):
    i = lo+1 #Initializing i with lo + 1
    pivot = ls[lo]  #Initializing pivot with ls[lo]
    while True: 
      if hi < i:  # Breaking loop whenever i pointer crosses hi
        break
      while pivot > ls[i] and hi > i: #Incrementing i until ith element of array is greater than or i value is greater than or equal to hi.
          i += 1
      while pivot < ls[hi] :  #Decrementing hi by 1 while element at hi pointer is greater than pivot.
          hi -= 1
      if hi > i : #if i value is less than hi then Swap elements at hi and i
          ls[i], ls[hi] = ls[hi], ls[i] #Swapping
          i += 1  # Incrementing i and decrementing hi
          hi -= 1
      else:
          i = i+1 #Incrementing only i otherwise
    ls[lo], ls[hi]= ls[hi], pivot #substitute lo with hi and swap hi with pivot.
    return hi
    
def quickSort(ls, lo, hi):
    if lo < hi:
      part = partition(ls, lo, hi) #returns, where to partion the array
      quickSort(ls, lo, part-1)  #Left sub array
      quickSort(ls, part+1, hi)  #Right sub array

# %%
class Product:
    def __init__(self, prodID, prodName, prodCategory, prodDescription, prodQuantity, prodPrice):
        self.prodID = prodID
        self.prodName = prodName
        self.prodCategory = prodCategory
        self.prodDescription = prodDescription
        self.prodQuantity = prodQuantity
        self.prodPrice = prodPrice
    #def addNewProd(self):
    #    Product.prods.append(self)
    #    print((Product.prods[-1]).prodID)
    def showProd(self):
        print("Product  :   Price   :   ID")
        for i in self.prods:
            print(i.prodName+"  :   ",i.prodPrice,"  :   ",i.prodID)
    def getProdList(self):
        return Product.prods
    def getProd(id):   #Linear search
        print(Product.prods)
        for i in Product.prods:
            if Product.prods[i].prodID == id:
                return Product.prods[i]
    def updateID(self,id):
        self.prodID = id
    def updateCategory(self,category):
        self.prodCategory = category
    def updateDescription(self,description):
        self.prodDescription = description
    def updateQuantity(self,quantity):
        self.prodQuantity = quantity
    def updatePrice(self,price):
        self.prodPrice = price
    def updateName(self,name):
        self.prodName = name

# %%
class Cart:
    orders = []
    def __init__(self,prods):
        self.prods = prods

    def addProd(self,id):
        for i in self.prods:
            if i.prodID == id:
                Cart.orders.append(i)

    def showProd(self):
        print("Product  :   Price   :   ID")
        for i in self.prods:
            print(i.prodName+"  :   ",i.prodPrice,"  :   ",i.prodID)

    def getCartValue(self):
        cartValue = 0
        for i in Cart.orders:
            cartValue += (i.prodPrice) * i.prodQuantity
        print("Total value: ",cartValue)

    def removeProd(self,id):
        for i in Cart.orders:
            if i.prodID == id:
                Cart.orders.remove(i)

    def getProd(self,id):   #search algo
        for i in Cart.orders:
            if i.prodID == id:
                return i
    def getProdDetails(self,id):   #search algo
        for i in self.prods:
            if i.prodID == id:
                print("ID :     ",i.prodID)
                print("Name :     ",i.prodName)
                print("Category :     ",i.prodCategory)
                print("Description :     ",i.prodDescription)
                print("Price :     ",i.prodPrice)
    def displayOrdersByPrice(self):
        idsInCart = []
        for i in Cart.orders:
            idsInCart.append(i.prodID)
        quickSort(idsInCart,0,len(idsInCart) - 1)
        for i in range(len(idsInCart)):
            tempObj = self.getProd(idsInCart[i])
            print("Name     Category     Description     Quantity    Total Price")
            print(tempObj.prodName, tempObj.prodCategory, tempObj.prodDescription, tempObj.prodQuantity, str((tempObj.prodPrice) * tempObj.prodQuantity)+"$", sep = "    ")

# %%
employees = []
class Business:
    def __init__(self, empID, empName, empPassword):
        self.empID = empID
        self.empID = empName
        self.empPassword = empPassword

# %%
for i in range(int(input("number of employees:"))) :

    empID = int(input("Employee ID of " +str(i+1)+ " : "))
    empName = input("Employee Name of " +str(i+1)+ " : ")
    empPassword = input("Employee password of " +str(i+1)+ " : ")

    eObj = Business(empID, empName, empPassword)


    employees.append(eObj)

# %%
prods = []

def productCreation():
    for i in range(int(input("number of products you want to enter:"))) :

        prodID = int(input("Product id of " +str(i+1)+ " : "))
        prodName = input("Product Name of " +str(i+1)+ " : ")
        prodCategory = input("Product Category of " +str(i+1)+ " : ")
        prodDescription = input("Product Desc of " +str(i+1)+ " : ")
        prodQuantity = int(input("Product Quantity of " +str(i+1)+ " : "))
        prodPrice = int(input("Product price of " +str(i+1)+ " : "))

        pObj = Product(prodID, prodName, prodCategory, prodDescription, prodQuantity, prodPrice)


        prods.append(pObj)
productCreation()

# %%
def validate(iD, pwd):
    print("called")
    for i in employees:
        print(i)
        if i.empID == iD and i.empPassword == pwd:
            print(i.empName)
            return True
    return False

while True:  
    print("\nMAIN MENU")  
    print("1. Are you an Employee?")  
    print("2. Are you a Customer?")  
    print("3. Exit")  
    choice1 = int(input("Enter the Choice:  "))  

    #Employee case
    if choice1 == 1:  
        empid = int(input("Enter Your ID: "))
        emppass = input("Enter Your Password: ")
        if validate(empid,emppass):
            print("in")
            print("\n Welcome Employee!") 
            while True:
                print("\n1. Show all products")  
                print("2. Add Product")  
                print("3. Remove Product")  
                print("4. Update product")  
                print("5. Exit")   
                choice3 = int(input("Enter the Choice:"))  

                if choice3 == 1:  
                    Product.showProd() 
                    
                elif choice3 == 2:  
                    productCreation()
                    
                elif choice3 == 3:  
                    updateObjID = int(input("Enter ID of product you want to update: "))
                    updatePara = input("Which parameter you want to update? /n prodID, prodName, prodCategory, prodDescription, prodQuantity, prodPrice")
                    updateObj = Product.getProd(updateObjID)
                    if updatePara == "prodID":
                        newVal = int(input("Enter new value: "))
                        Product.updateID(updateObj,newVal)
                    elif updatePara == "prodPrice":
                        newVal = int(input("Enter new value: "))
                        Product.updatePrice(updateObj,newVal)
                    elif updatePara == "prodQuantity":
                        newVal = int(input("Enter new value: "))
                        Product.updateQuantity(updateObj,newVal)
                    elif updatePara == "prodName":
                        newVal = input("Enter new value: ")
                        Product.updateName(updateObj,newVal)
                    elif updatePara == "prodCategory":
                        newVal = input("Enter new value: ")
                        Product.updateCategory(updateObj,newVal)
                    elif updatePara == "prodDescription":
                        newVal = input("Enter new value: ")
                        Product.updateDescription(updateObj,newVal)
                    

                elif choice3 == 4:  
                    idToAdd = int(input("Product id to add to cart: "))
                    c.addProd(idToAdd)
                    print("Added!")

                elif choice3 == 5:  
                    break  
                    
                else:  
                    print("Oops! Incorrect Choice.")  
            
    #Employee Menu till here

    #Customer Menu
    elif choice1 == 2:  
        print("\n Welcome Customer!") 
        while True:
            print("\n1. Show all products")  
            print("2. Full details of products by ID")  
            print("3. Cart Total value")  
            print("4. Add product")  
            print("5. Remove product")  
            print("6. Show cart sorted by Price") 
            print("7. Exit")   
            choice3 = int(input("Enter the Choice:"))  

            c = Cart(prods)

            if choice3 == 1:  
                Product.showProd() 
                
            elif choice3 == 2:  
                idFullDetails = int(input("Enter ID of product for full details: "))
                c.getProdDetails(idFullDetails)
                
            elif choice3 == 3:  
                c.getCartValue()

            elif choice3 == 4:  
                idToAdd = int(input("Product id to add to cart: "))
                c.addProd(idToAdd)
                print("Added!")

            elif choice3 == 5:  
                idToRemove = int(input("Product id to remove from cart: "))
                c.removeProd(idToRemove)
                print("Removed!")

            elif choice3 == 6:  
                c.displayOrdersByPrice()

            elif choice3 == 7:  
                break  
                
            else:  
                print("Oops! Incorrect Choice.")  
        
    elif choice1 == 3:  
        break  
      
    else:  
        print("Oops! Incorrect Choice.")
# Out:
# MAIN MENU
# 1. Are you an Employee?
# 2. Are you a Customer?
# 3. Exit
# in
# called
# ...
#
# MAIN MENU
# 1. Are you an Employee?
# 2. Are you a Customer?
# 3. Exit
# in
# called
# ...
#
# MAIN MENU
# 1. Are you an Employee?
# 2. Are you a Customer?
# 3. Exit
#
#  Welcome Customer!
#
# 1. Show all products
# 2. Full details of products by ID
# 3. Cart Total value
# 4. Add product
# 5. Remove product
# 6. Show cart sorted by Price
# 7. Exit
# ID :      1
# Name :      Mac
# Category :      lap
# Description :      1
# Price :      1000
#
# 1. Show all products
# 2. Full details of products by ID
# 3. Cart Total value
# 4. Add product
# 5. Remove product
# 6. Show cart sorted by Price
# 7. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/abhishekthamatam/Desktop/UMBC/690 DSA/Project/Ecommerce.ipynb Cell 7 in <cell line: 11>()
# ...
