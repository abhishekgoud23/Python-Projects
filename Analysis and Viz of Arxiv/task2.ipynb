# %% [markdown]
# ## Using the stored data from the last task, creating dataframes for each primary category

# %% [markdown]
# ### Importing required Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Importing csv file using pandas as DataFrame

# %%
df = pd.read_csv("task1.csv")      #Reading csv file using read_csv() of pandas library to data frame
df                                 #Dataframe
# Out:
#        Unnamed: 0                                              title  \
# 0               0  Even $1 \times n$ Edge-Matching and Jigsaw Puz...
# 1               1  NIPS 2016 Tutorial: Generative Adversarial Net...
# 2               2  Classification of Smartphone Users Using Inter...
# 3               3  Closed Sets and Operators thereon: Representat...
# 4               4                     Outlier Robust Online Learning
# ...           ...                                                ...
# 47067       29578  Fast Learning of MNL Model from General Partia...
# 47068       29579  How Infinitely Wide Neural Networks Can Benefi...
# 47069       29580  Importance of Empirical Sample Complexity Anal...
# 47070       29581  Single-Shot Pruning for Offline Reinforcement ...
# 47071       29582  A Neural Network Solves, Explains, and Generat...
#
#                                                  authors  \
# 0      ['Jeffrey Bosboom', 'Erik D. Demaine', 'Martin...
# 1                                     ['Ian Goodfellow']
# 2      ['Andrey Finkelstein', 'Ron Biton', 'Rami Puzi...
# 3                         ['Carsten Rösnick-Neugebauer']
# 4              ['Jiashi Feng', 'Huan Xu', 'Shie Mannor']
# ...                                                  ...
# 47067      ['Jiaqi Ma', 'Xingjian Zhang', 'Qiaozhu Mei']
# 47068  ['Jakob Heiss', 'Josef Teichmann', 'Hanna Wutte']
# 47069  ['Samin Yeasar Arnob', 'Riashat Islam', 'Doina...
# 47070  ['Samin Yeasar Arnob', 'Riyasat Ohib', 'Sergey...
# 47071  ['Iddo Drori', 'Sarah Zhang', 'Reece Shuttlewo...
#
#                                                  summary  \
# 0      We prove the computational intractability of r...
# 1      This report summarizes the tutorial presented ...
# 2      Today, smartphone devices are owned by a large...
# 3      The TTE approach to Computable Analysis is the...
# 4      We consider the problem of learning from noisy...
# ...                                                  ...
# 47067  Multinomial Logit (MNL) is one of the most pop...
# 47068  In practice, multi-task learning (through lear...
# 47069  We hypothesize that empirically studying the s...
# 47070  Deep Reinforcement Learning (RL) is a powerful...
# 47071  We demonstrate that a neural network pre-train...
#
#                                                  comment  \
# 0                                    22 pages, 9 figures
# 1      v2-v4 are all typo fixes. No substantive chang...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 47067                                          WSDM 2022
# 47068                                13 pages + appendix
# 47069                                                NaN
# 47070                                                NaN
# 47071                   181 pages, 8 figures, 280 tables
#
#                                              journal_ref  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Logical Methods in Computer Science, Volume 14...
# 4                                                    NaN
# ...                                                  ...
# 47067                                                NaN
# 47068                                                NaN
# 47069                                                NaN
# 47070                                                NaN
# 47071                                                NaN
#
#                              doi                           entry_id  \
# 0                            NaN  http://arxiv.org/abs/1701.00146v1
# 1                            NaN  http://arxiv.org/abs/1701.00160v4
# 2                            NaN  http://arxiv.org/abs/1701.00220v1
# 3      10.23638/LMCS-14(2:1)2018  http://arxiv.org/abs/1701.00227v4
# 4                            NaN  http://arxiv.org/abs/1701.00251v1
# ...                          ...                                ...
# 47067                        NaN  http://arxiv.org/abs/2112.15575v1
# 47068   10.3929/ethz-b-000550890  http://arxiv.org/abs/2112.15577v4
# 47069                        NaN  http://arxiv.org/abs/2112.15578v1
# 47070                        NaN  http://arxiv.org/abs/2112.15579v1
# 47071    10.1073/pnas.2123433119  http://arxiv.org/abs/2112.15594v4
#
#                          updated                  published primary_category  \
# 0      2016-12-31 17:05:53+00:00  2016-12-31 17:05:53+00:00            cs.CC
# 1      2017-04-03 21:57:48+00:00  2016-12-31 19:17:17+00:00            cs.LG
# 2      2017-01-01 08:12:49+00:00  2017-01-01 08:12:49+00:00            cs.LG
# 3      2018-04-09 07:07:33+00:00  2017-01-01 11:25:42+00:00            cs.CC
# 4      2017-01-01 15:18:13+00:00  2017-01-01 15:18:13+00:00            cs.LG
# ...                          ...                        ...              ...
# 47067  2021-12-31 18:00:45+00:00  2021-12-31 18:00:45+00:00            cs.LG
# 47068  2022-10-20 15:03:17+00:00  2021-12-31 18:03:46+00:00            cs.LG
# 47069  2021-12-31 18:05:33+00:00  2021-12-31 18:05:33+00:00            cs.LG
# 47070  2021-12-31 18:10:02+00:00  2021-12-31 18:10:02+00:00            cs.LG
# 47071  2022-05-30 20:21:46+00:00  2021-12-31 18:57:31+00:00            cs.LG
#
#                                             categories  \
# 0                                   ['cs.CC', 'cs.CG']
# 1                                            ['cs.LG']
# 2                                   ['cs.LG', 'cs.CR']
# 3      ['cs.CC', 'cs.LO', 'math.LO', '03D15', 'F.4.1']
# 4                                 ['cs.LG', 'stat.ML']
# ...                                                ...
# 47067                      ['cs.LG', 'cs.AI', 'cs.IR']
# 47068      ['cs.LG', 'stat.ML', '68T07, 68Q32', 'I.2']
# 47069                               ['cs.LG', 'cs.AI']
# 47070                                        ['cs.LG']
# 47071                               ['cs.LG', 'cs.AI']
#
#                                                    links  \
# 0      [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 1      [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 2      [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 3      [arxiv.Result.Link('http://dx.doi.org/10.23638...
# 4      [arxiv.Result.Link('http://arxiv.org/abs/1701....
# ...                                                  ...
# 47067  [arxiv.Result.Link('http://arxiv.org/abs/2112....
# 47068  [arxiv.Result.Link('http://dx.doi.org/10.3929/...
# 47069  [arxiv.Result.Link('http://arxiv.org/abs/2112....
# 47070  [arxiv.Result.Link('http://arxiv.org/abs/2112....
# 47071  [arxiv.Result.Link('http://dx.doi.org/10.1073/...
#
#                                  pdf_url
# 0      http://arxiv.org/pdf/1701.00146v1
# 1      http://arxiv.org/pdf/1701.00160v4
# 2      http://arxiv.org/pdf/1701.00220v1
# 3      http://arxiv.org/pdf/1701.00227v4
# 4      http://arxiv.org/pdf/1701.00251v1
# ...                                  ...
# 47067  http://arxiv.org/pdf/2112.15575v1
# 47068  http://arxiv.org/pdf/2112.15577v4
# 47069  http://arxiv.org/pdf/2112.15578v1
# 47070  http://arxiv.org/pdf/2112.15579v1
# 47071  http://arxiv.org/pdf/2112.15594v4
#
# [47072 rows x 14 columns]

# %% [markdown]
# ### Creating Data Frame for each category

# %%
dfAI = df.loc[(df['primary_category'] == 'cs.AI')]     #dfAI is dataframe whose primary category is cs.AI
dfAI.head()                                            #head() is used to print first 5 rows
# Out:
#     Unnamed: 0                                              title  \
# 5            5                STRIPS Planning in Infinite Domains
# 7            7  An affective computational model for machine c...
# 8            8  Conceptual Spaces for Cognitive Architectures:...
# 12          12  Finding Risk-Averse Shortest Path with Time-de...
# 13          13  From Preference-Based to Multiobjective Sequen...
#
#                                               authors  \
# 5   ['Caelan Reed Garrett', 'Tomás Lozano-Pérez', ...
# 7                                ['Rohitash Chandra']
# 8   ['Antonio Lieto', 'Antonio Chella', 'Marcello ...
# 12    ['Dajian Li', 'Paul Weng', 'Orkun Karabasoglu']
# 13                                      ['Paul Weng']
#
#                                               summary  \
# 5   Many robotic planning applications involve con...
# 7   In the past, several models of consciousness h...
# 8   During the last decades, many cognitive archit...
# 12  In this paper, we tackle the problem of risk-a...
# 13  In this paper, we present a link between prefe...
#
#                                               comment journal_ref  \
# 5                                            11 pages         NaN
# 7                                        under review         NaN
# 8   31 pages, 3 figures in Biologically Inspired C...         NaN
# 12                             accepted at MIWAI 2017         NaN
# 13                             accepted at MIWAI 2017         NaN
#
#                              doi                           entry_id  \
# 5                            NaN  http://arxiv.org/abs/1701.00287v2
# 7                            NaN  http://arxiv.org/abs/1701.00349v1
# 8     10.1016/j.bica.2016.10.005  http://arxiv.org/abs/1701.00464v1
# 12   10.1007/978-3-319-49397-8_9  http://arxiv.org/abs/1701.00642v1
# 13  10.1007/978-3-319-49397-8_20  http://arxiv.org/abs/1701.00646v1
#
#                       updated                  published primary_category  \
# 5   2017-05-28 01:08:00+00:00  2017-01-01 20:37:51+00:00            cs.AI
# 7   2017-01-02 09:48:47+00:00  2017-01-02 09:48:47+00:00            cs.AI
# 8   2017-01-02 17:35:34+00:00  2017-01-02 17:35:34+00:00            cs.AI
# 12  2017-01-03 10:47:35+00:00  2017-01-03 10:47:35+00:00            cs.AI
# 13  2017-01-03 10:57:06+00:00  2017-01-03 10:57:06+00:00            cs.AI
#
#    categories                                              links  \
# 5   ['cs.AI']  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 7   ['cs.AI']  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 8   ['cs.AI']  [arxiv.Result.Link('http://dx.doi.org/10.1016/...
# 12  ['cs.AI']  [arxiv.Result.Link('http://dx.doi.org/10.1007/...
# 13  ['cs.AI']  [arxiv.Result.Link('http://dx.doi.org/10.1007/...
#
#                               pdf_url
# 5   http://arxiv.org/pdf/1701.00287v2
# 7   http://arxiv.org/pdf/1701.00349v1
# 8   http://arxiv.org/pdf/1701.00464v1
# 12  http://arxiv.org/pdf/1701.00642v1
# 13  http://arxiv.org/pdf/1701.00646v1

# %%
dfCC = df.loc[(df['primary_category'] == 'cs.CC')]     #dfCC is dataframe whose primary category is cs.CC
dfCC.head()                                            #head() is used to print first 5 rows
# Out:
#     Unnamed: 0                                              title  \
# 0            0  Even $1 \times n$ Edge-Matching and Jigsaw Puz...
# 3            3  Closed Sets and Operators thereon: Representat...
# 28          28  Understanding the complexity of #SAT using kno...
# 29          29  Non interactive simulation of correlated distr...
# 33          33  Towards an algebraic natural proofs barrier vi...
#
#                                               authors  \
# 0   ['Jeffrey Bosboom', 'Erik D. Demaine', 'Martin...
# 3                      ['Carsten Rösnick-Neugebauer']
# 28                                ['Florent Capelli']
# 29    ['Anindya De', 'Elchanan Mossel', 'Joe Neeman']
# 33  ['Joshua A. Grochow', 'Mrinal Kumar', 'Michael...
#
#                                               summary  \
# 0   We prove the computational intractability of r...
# 3   The TTE approach to Computable Analysis is the...
# 28  Two main techniques have been used so far to s...
# 29  A basic problem in information theory is the f...
# 33  We observe that a certain kind of algebraic pr...
#
#                                               comment  \
# 0                                 22 pages, 9 figures
# 3                                                 NaN
# 28                                                NaN
# 29  The reduction for non-interactive simulation f...
# 33                                                NaN
#
#                                           journal_ref  \
# 0                                                 NaN
# 3   Logical Methods in Computer Science, Volume 14...
# 28                                                NaN
# 29                                                NaN
# 33                                                NaN
#
#                           doi                           entry_id  \
# 0                         NaN  http://arxiv.org/abs/1701.00146v1
# 3   10.23638/LMCS-14(2:1)2018  http://arxiv.org/abs/1701.00227v4
# 28                        NaN  http://arxiv.org/abs/1701.01461v1
# 29                        NaN  http://arxiv.org/abs/1701.01485v2
# 33                        NaN  http://arxiv.org/abs/1701.01717v1
#
#                       updated                  published primary_category  \
# 0   2016-12-31 17:05:53+00:00  2016-12-31 17:05:53+00:00            cs.CC
# 3   2018-04-09 07:07:33+00:00  2017-01-01 11:25:42+00:00            cs.CC
# 28  2017-01-05 19:48:01+00:00  2017-01-05 19:48:01+00:00            cs.CC
# 29  2017-02-15 19:52:21+00:00  2017-01-05 21:31:56+00:00            cs.CC
# 33  2017-01-06 18:27:48+00:00  2017-01-06 18:27:48+00:00            cs.CC
#
#                                            categories  \
# 0                                  ['cs.CC', 'cs.CG']
# 3     ['cs.CC', 'cs.LO', 'math.LO', '03D15', 'F.4.1']
# 28                                 ['cs.CC', 'cs.AI']
# 29           ['cs.CC', 'cs.IT', 'math.IT', 'math.PR']
# 33  ['cs.CC', 'math.AG', '68Q15, 68Q17, 68W30, 14Q...
#
#                                                 links  \
# 0   [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 3   [arxiv.Result.Link('http://dx.doi.org/10.23638...
# 28  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 29  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 33  [arxiv.Result.Link('http://arxiv.org/abs/1701....
#
#                               pdf_url
# 0   http://arxiv.org/pdf/1701.00146v1
# 3   http://arxiv.org/pdf/1701.00227v4
# 28  http://arxiv.org/pdf/1701.01461v1
# 29  http://arxiv.org/pdf/1701.01485v2
# 33  http://arxiv.org/pdf/1701.01717v1

# %%
dfLG = df.loc[(df['primary_category'] == 'cs.LG')]     #dfLG is dataframe whose primary category is cs.LG
dfLG.head()                                            #head() is used to print first 5 rows
# Out:
#    Unnamed: 0                                              title  \
# 1           1  NIPS 2016 Tutorial: Generative Adversarial Net...
# 2           2  Classification of Smartphone Users Using Inter...
# 4           4                     Outlier Robust Online Learning
# 6           6  Dynamic Deep Neural Networks: Optimizing Accur...
# 9           9  Two-Bit Networks for Deep Learning on Resource...
#
#                                              authors  \
# 1                                 ['Ian Goodfellow']
# 2  ['Andrey Finkelstein', 'Ron Biton', 'Rami Puzi...
# 4          ['Jiashi Feng', 'Huan Xu', 'Shie Mannor']
# 6                         ['Lanlan Liu', 'Jia Deng']
# 9  ['Wenjia Meng', 'Zonghua Gu', 'Ming Zhang', 'Z...
#
#                                              summary  \
# 1  This report summarizes the tutorial presented ...
# 2  Today, smartphone devices are owned by a large...
# 4  We consider the problem of learning from noisy...
# 6  We introduce Dynamic Deep Neural Networks (D2N...
# 9  With the rapid proliferation of Internet of Th...
#
#                                              comment journal_ref  doi  \
# 1  v2-v4 are all typo fixes. No substantive chang...         NaN  NaN
# 2                                                NaN         NaN  NaN
# 4                                                NaN         NaN  NaN
# 6  fixed typos; updated CIFAR-10 results and adde...         NaN  NaN
# 9                                                NaN         NaN  NaN
#
#                             entry_id                    updated  \
# 1  http://arxiv.org/abs/1701.00160v4  2017-04-03 21:57:48+00:00
# 2  http://arxiv.org/abs/1701.00220v1  2017-01-01 08:12:49+00:00
# 4  http://arxiv.org/abs/1701.00251v1  2017-01-01 15:18:13+00:00
# 6  http://arxiv.org/abs/1701.00299v3  2018-03-05 02:03:00+00:00
# 9  http://arxiv.org/abs/1701.00485v2  2017-01-04 13:54:51+00:00
#
#                    published primary_category            categories  \
# 1  2016-12-31 19:17:17+00:00            cs.LG             ['cs.LG']
# 2  2017-01-01 08:12:49+00:00            cs.LG    ['cs.LG', 'cs.CR']
# 4  2017-01-01 15:18:13+00:00            cs.LG  ['cs.LG', 'stat.ML']
# 6  2017-01-02 00:09:14+00:00            cs.LG  ['cs.LG', 'stat.ML']
# 9  2017-01-02 04:28:16+00:00            cs.LG    ['cs.LG', 'cs.CV']
#
#                                                links  \
# 1  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 2  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 4  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 6  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 9  [arxiv.Result.Link('http://arxiv.org/abs/1701....
#
#                              pdf_url
# 1  http://arxiv.org/pdf/1701.00160v4
# 2  http://arxiv.org/pdf/1701.00220v1
# 4  http://arxiv.org/pdf/1701.00251v1
# 6  http://arxiv.org/pdf/1701.00299v3
# 9  http://arxiv.org/pdf/1701.00485v2

# %%
dfAR = df.loc[(df['primary_category'] == 'cs.AR')]     #dfAR is dataframe whose primary category is cs.AR
dfAR.head()                                            #head() is used to print first 5 rows
# Out:
#      Unnamed: 0                                              title  \
# 32           32  Reducing Competitive Cache Misses in Modern Pr...
# 68           68    VESPA: VIPT Enhancements for Superpage Accesses
# 79           79        HoLiSwap: Reducing Wire Energy in L1 Caches
# 131         131            Design of an Audio Interface for Patmos
# 134         134  Neurostream: Scalable and Energy Efficient Dee...
#
#                                                authors  \
# 32            ['Milcho Prisagjanec', 'Pece Mitrevski']
# 68   ['Mayank Parasar', 'Abhishek Bhattacharjee', '...
# 79   ['Yatish Turakhia', 'Subhasis Das', 'Tor M. Aa...
# 131             ['Daniel Sanz Ausin', 'Fabian Goerge']
# 134  ['Erfan Azarkhish', 'Davide Rossi', 'Igor Loi'...
#
#                                                summary  \
# 32   The increasing number of threads inside the co...
# 68   L1 caches are critical to the performance of m...
# 79   This paper describes HoLiSwap a method to redu...
# 131  This paper describes the design and implementa...
# 134  High-performance computing systems are moving ...
#
#                                                comment  \
# 32                         9 pages, 8 figures, 1 table
# 68                                                 NaN
# 79                                                 NaN
# 131                                                NaN
# 134  14 pages, 13 figures, submitted to IEEE TPDS J...
#
#                                            journal_ref  \
# 32   International Journal of Computer Science & In...
# 68                                                 NaN
# 79                                                 NaN
# 131                                                NaN
# 134                                                NaN
#
#                            doi                           entry_id  \
# 32    10.5121/ijcsit.2016.8605  http://arxiv.org/abs/1701.01630v1
# 68                         NaN  http://arxiv.org/abs/1701.03499v2
# 79                         NaN  http://arxiv.org/abs/1701.03878v1
# 131                        NaN  http://arxiv.org/abs/1701.06382v1
# 134  10.1109/TPDS.2017.2752706  http://arxiv.org/abs/1701.06420v3
#
#                        updated                  published primary_category  \
# 32   2017-01-06 13:32:36+00:00  2017-01-06 13:32:36+00:00            cs.AR
# 68   2017-02-14 07:58:57+00:00  2017-01-12 20:31:53+00:00            cs.AR
# 79   2017-01-14 04:03:50+00:00  2017-01-14 04:03:50+00:00            cs.AR
# 131  2017-01-23 13:40:16+00:00  2017-01-23 13:40:16+00:00            cs.AR
# 134  2017-09-24 17:47:10+00:00  2017-01-23 14:44:47+00:00            cs.AR
#
#                     categories  \
# 32   ['cs.AR', 'B.3.2; B.3.3']
# 68          ['cs.AR', '68-06']
# 79                   ['cs.AR']
# 131                  ['cs.AR']
# 134         ['cs.AR', 'cs.ET']
#
#                                                  links  \
# 32   [arxiv.Result.Link('http://dx.doi.org/10.5121/...
# 68   [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 79   [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 131  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 134  [arxiv.Result.Link('http://dx.doi.org/10.1109/...
#
#                                pdf_url
# 32   http://arxiv.org/pdf/1701.01630v1
# 68   http://arxiv.org/pdf/1701.03499v2
# 79   http://arxiv.org/pdf/1701.03878v1
# 131  http://arxiv.org/pdf/1701.06382v1
# 134  http://arxiv.org/pdf/1701.06420v3
